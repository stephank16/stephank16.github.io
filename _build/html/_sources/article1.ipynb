# %% [markdown]
# # Emotional capacity and relating
#
# ...
# share my experience with very time and place dependent emotional capacity and its effect on relating .. and training the emotional muscle ...
